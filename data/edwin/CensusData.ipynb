# %%
import pandas as pd

df = pd.read_csv("ProjectData.csv")

# Create a list of dictionaries containing the data for each county.

df.drop(columns = ['State', 'Area_Name'], inplace=True)
df.rename(columns = {"FIP_ID":"id"}, inplace=True)

NCCVFatalityData = df.to_dict('records')

# %%
NCCVFatalityData
# Out:
# [{'id': 1,
#   'Overall Poverty 2017': 22721,
#   'Median_Household_Income_2017': 47914,
#   'POP_ESTIMATE_2017': 163529,
#   'POP_ESTIMATE_2018': 166436,
#   'N_POP_CHG_2017': 3137,
#   'N_POP_CHG_2018': 2907,
#   'Births_2017': 1911,
#   'Births_2018': 1895,
#   'Deaths_2017': 1590,
#   'Deaths_2018': 1623,
#   'INTERNATIONAL_MIG_2017': 107,
#   'INTERNATIONAL_MIG_2018': 116,
#   'DOMESTIC_MIG_2017': 2703,
#   'DOMESTIC_MIG_2018': 2511,
#   'NET_MIG_2017': 2810,
#   'NET_MIG_2018': 2627,
#   'R_death_2017': 10,
#   'R_death_2018': 10,
#   'Less than a high school diploma  2013-17': 16058,
#   'High school diploma only  2013-17': 29752,
#   'Some college  associates degree  2013-17': 36294,
#   'Bachelors degree higher  2013-17': 24339,
#   'Percent of adults with less than a high school diploma  2013-17': 15,
#   'Percent of adults with a high school diploma only  2013-17': 28,
#   'Percent of adults completing some college or associates degree  2013-17': 34,
#   'Percent of adults with a bachelors degree or higher  2013-17': 23,
#   'Civilian_labor_force_2017': 79984,
#   'Employed_2017': 76611,
#   'Unemployed_2017': 3373,
#   'Unemployment_rate_2017': 4,
#   'Civilian_labor_force_2018': 80583,
#   'Employed_2018': 77625,
#   'Unemployed_2018': 2958,
#   'Unemployment_rate_2018': 4,
#   'Median_Household_Income_2017.1': 47914},
#  {'id': 3,
#   'Overall Poverty 2017': 4182,
#   'Median_Household_Income_2017': 48577,
#   'POP_ESTIMATE_2017': 37146,
#   'POP_ESTIMATE_2018': 37353,
#   'N_POP_CHG_2017': 4,
#   'N_POP_CHG_2018': 207,
#   'Births_2017': 355,
#   'Births_2018': 356,
#   'Deaths_2017': 387,
#   'Deaths_2018': 391,
#   'INTERNATIONAL_MIG_2017': 7,
#   'INTERNATIONAL_MIG_2018': 7,
#   'DOMESTIC_MIG_2017': 29,
#   'DOMESTIC_MIG_2018': 237,
#   'NET_MIG_2017': 36,
#   'NET_MIG_2018': 244,
#   'R_death_2017': 10,
#   'R_death_2018': 11,
#   'Less than a high school diploma  2013-17': 4805,
#   'High school diploma only  2013-17': 10600,
#   'Some college  associates degree  2013-17': 7471,
#   'Bachelors degree higher  2013-17': 3685,
#   'Percent of adults with less than a high school diploma  2013-17': 18,
#   'Percent of adults with a high school diploma only  2013-17': 40,
#   'Percent of adults completing some college or associates degree  2013-17': 28,
#   'Percent of adults with a bachelors degree or higher  2013-17': 14,
#   'Civilian_labor_force_2017': 17982,
#   'Employed_2017': 17334,
#   'Unemployed_2017': 648,
#   'Unemployment_rate_2017': 4,
#   'Civilian_labor_force_2018': 18023,
#   'Employed_2018': 17453,
#   'Unemployed_2018': 570,
#   'Unemployment_rate_2018': 3,
#   'Median_Household_Income_2017.1': 48577},
#  {'id': 5,
#   'Overall Poverty 2017': 2274,
#   'Median_Household_Income_2017': 38994,
#   'POP_ESTIMATE_2017': 11023,
#   'POP_ESTIMATE_2018': 11161,
#   'N_POP_CHG_2017': 97,
#   'N_POP_CHG_2018': 138,
#   'Births_2017': 100,
#   'Births_2018': 97,
#   'Deaths_2017': 125,
#   'Deaths_2018': 135,
#   'INTERNATIONAL_MIG_2017': 2,
#   'INTERNATIONAL_MIG_2018': 2,
#   'DOMESTIC_MIG_2017': 120,
#   'DOMESTIC_MIG_2018': 173,
#   'NET_MIG_2017': 122,
#   'NET_MIG_2018': 175,
#   'R_death_2017': 11,
#   'R_death_2018': 12,
#   'Less than a high school diploma  2013-17': 1708,
#   'High school diploma only  2013-17': 2487,
#   'Some college  associates degree  2013-17': 2371,
#   'Bachelors degree higher  2013-17': 1510,
#   'Percent of adults with less than a high school diploma  2013-17': 21,
#   'Percent of adults with a high school diploma only  2013-17': 31,
#   'Percent of adults completing some college or associates degree  2013-17': 29,
#   'Percent of adults with a bachelors degree or higher  2013-17': 19,
#   'Civilian_labor_force_2017': 4364,
#   'Employed_2017': 4145,
#   'Unemployed_2017': 219,
#   'Unemployment_rate_2017': 5,
#   'Civilian_labor_force_2018': 4305,
#   'Employed_2018': 4111,
#   'Unemployed_2018': 194,
#   'Unemployment_rate_2018': 5,
#   'Median_Household_Income_2017.1': 38994},
#  {'id': 7,
#   'Overall Poverty 2017': 5039,
#   'Median_Household_Income_2017': 41266,
#   'POP_ESTIMATE_2017': 24878,
#   'POP_ESTIMATE_2018': 24877,
#   'N_POP_CHG_2017': -304,
#   'N_POP_CHG_2018': -1,
#   'Births_2017': 255,
#   'Births_2018': 256,
#   'Deaths_2017': 285,
#   'Deaths_2018': 267,
#   'INTERNATIONAL_MIG_2017': 29,
#   'INTERNATIONAL_MIG_2018': 30,
#   'DOMESTIC_MIG_2017': -306,
#   'DOMESTIC_MIG_2018': -20,
#   'NET_MIG_2017': -277,
#   'NET_MIG_2018': 10,
#   'R_death_2017': 11,
#   'R_death_2018': 11,
#   'Less than a high school diploma  2013-17': 3605,
#   'High school diploma only  2013-17': 7455,
#   'Some college  associates degree  2013-17': 5352,
#   'Bachelors degree higher  2013-17': 1669,
#   'Percent of adults with less than a high school diploma  2013-17': 20,
#   'Percent of adults with a high school diploma only  2013-17': 41,
#   'Percent of adults completing some college or associates degree  2013-17': 30,
#   'Percent of adults with a bachelors degree or higher  2013-17': 9,
#   'Civilian_labor_force_2017': 10530,
#   'Employed_2017': 9991,
#   'Unemployed_2017': 539,
#   'Unemployment_rate_2017': 5,
#   'Civilian_labor_force_2018': 10407,
#   'Employed_2018': 9942,
#   'Unemployed_2018': 465,
#   'Unemployment_rate_2018': 5,
#   'Median_Household_Income_2017.1': 41266},
#  {'id': 9,
#   'Overall Poverty 2017': 4267,
#   'Median_Household_Income_2017': 40611,
#   'POP_ESTIMATE_2017': 26803,
#   'POP_ESTIMATE_2018': 27109,
#   'N_POP_CHG_2017': 192,
#   'N_POP_CHG_2018': 306,
#   'Births_2017': 213,
#   'Births_2018': 207,
#   'Deaths_2017': 330,
#   'Deaths_2018': 355,
#   'INTERNATIONAL_MIG_2017': -6,
#   'INTERNATIONAL_MIG_2018': -7,
#   'DOMESTIC_MIG_2017': 315,
#   'DOMESTIC_MIG_2018': 459,
#   'NET_MIG_2017': 309,
#   'NET_MIG_2018': 452,
#   'R_death_2017': 12,
#   'R_death_2018': 13,
#   'Less than a high school diploma  2013-17': 3042,
#   'High school diploma only  2013-17': 6337,
#   'Some college  associates degree  2013-17': 6884,
#   'Bachelors degree higher  2013-17': 3944,
#   'Percent of adults with less than a high school diploma  2013-17': 15,
#   'Percent of adults with a high school diploma only  2013-17': 31,
#   'Percent of adults completing some college or associates degree  2013-17': 34,
#   'Percent of adults with a bachelors degree or higher  2013-17': 20,
#   'Civilian_labor_force_2017': 12669,
#   'Employed_2017': 12153,
#   'Unemployed_2017': 516,
#   'Unemployment_rate_2017': 4,
#   'Civilian_labor_force_2018': 12750,
#   'Employed_2018': 12292,
#   'Unemployed_2018': 458,
#   'Unemployment_rate_2018': 4,
#   'Median_Household_Income_2017.1': 40611},
#  {'id': 11,
#   'Overall Poverty 2017': 2806,
#   'Median_Household_Income_2017': 40682,
#   'POP_ESTIMATE_2017': 17505,
#   'POP_ESTIMATE_2018': 17505,
#   'N_POP_CHG_2017': 82,
#   'N_POP_CHG_2018': 0,
#   'Births_2017': 134,
#   'Births_2018': 130,
#   'Deaths_2017': 174,
#   'Deaths_2018': 215,
#   'INTERNATIONAL_MIG_2017': 17,
#   'INTERNATIONAL_MIG_2018': 17,
#   'DOMESTIC_MIG_2017': 106,
#   'DOMESTIC_MIG_2018': 69,
#   'NET_MIG_2017': 123,
#   'NET_MIG_2018': 86,
#   'R_death_2017': 10,
#   'R_death_2018': 12,
#   'Less than a high school diploma  2013-17': 2574,
#   'High school diploma only  2013-17': 3973,
#   'Some college  associates degree  2013-17': 4001,
#   'Bachelors degree higher  2013-17': 2677,
#   'Percent of adults with less than a high school diploma  2013-17': 20,
#   'Percent of adults with a high school diploma only  2013-17': 30,
#   'Percent of adults completing some college or associates degree  2013-17': 30,
#   'Percent of adults with a bachelors degree or higher  2013-17': 20,
#   'Civilian_labor_force_2017': 7643,
#   'Employed_2017': 7318,
#   'Unemployed_2017': 325,
#   'Unemployment_rate_2017': 4,
#   'Civilian_labor_force_2018': 7639,
#   'Employed_2018': 7361,
#   'Unemployed_2018': 278,
#   'Unemployment_rate_2018': 4,
#   'Median_Household_Income_2017.1': 40682},
#  {'id': 13,
#   'Overall Poverty 2017': 10260,
#   'Median_Household_Income_2017': 43497,
#   'POP_ESTIMATE_2017': 47051,
#   'POP_ESTIMATE_2018': 47079,
#   'N_POP_CHG_2017': -319,
#   'N_POP_CHG_2018': 28,
#   'Births_2017': 458,
#   'Births_2018': 439,
#   'Deaths_2017': 640,
#   'Deaths_2018': 620,
#   'INTERNATIONAL_MIG_2017': 4,
#   'INTERNATIONAL_MIG_2018': 4,
#   'DOMESTIC_MIG_2017': -137,
#   'DOMESTIC_MIG_2018': 206,
#   'NET_MIG_2017': -133,
#   'NET_MIG_2018': 210,
#   'R_death_2017': 14,
#   'R_death_2018': 13,
#   'Less than a high school diploma  2013-17': 4759,
#   'High school diploma only  2013-17': 11353,
#   'Some college  associates degree  2013-17': 11084,
#   'Bachelors degree higher  2013-17': 6639,
#   'Percent of adults with less than a high school diploma  2013-17': 14,
#   'Percent of adults with a high school diploma only  2013-17': 34,
#   'Percent of adults completing some college or associates degree  2013-17': 33,
#   'Percent of adults with a bachelors degree or higher  2013-17': 20,
#   'Civilian_labor_force_2017': 19999,
#   'Employed_2017': 18998,
#   'Unemployed_2017': 1001,
#   'Unemployment_rate_2017': 5,
#   'Civilian_labor_force_2018': 19739,
#   'Employed_2018': 18839,
#   'Unemployed_2018': 900,
#   'Unemployment_rate_2018': 5,
#   'Median_Household_Income_2017.1': 43497},
#  {'id': 15,
#   'Overall Poverty 2017': 4896,
#   'Median_Household_Income_2017': 33022,
#   'POP_ESTIMATE_2017': 19274,
#   'POP_ESTIMATE_2018': 19026,
#   'N_POP_CHG_2017': -158,
#   'N_POP_CHG_2018': -248,
#   'Births_2017': 181,
#   'Births_2018': 172,
#   'Deaths_2017': 244,
#   'Deaths_2018': 262,
#   'INTERNATIONAL_MIG_2017': 21,
#   'INTERNATIONAL_MIG_2018': 21,
#   'DOMESTIC_MIG_2017': -116,
#   'DOMESTIC_MIG_2018': -177,
#   'NET_MIG_2017': -95,
#   'NET_MIG_2018': -156,
#   'R_death_2017': 13,
#   'R_death_2018': 14,
#   'Less than a high school diploma  2013-17': 3502,
#   'High school diploma only  2013-17': 5432,
#   'Some college  associates degree  2013-17': 3921,
#   'Bachelors degree higher  2013-17': 1802,
#   'Percent of adults with less than a high school diploma  2013-17': 24,
#   'Percent of adults with a high school diploma only  2013-17': 37,
#   'Percent of adults completing some college or associates degree  2013-17': 27,
#   'Percent of adults with a bachelors degree or higher  2013-17': 12,
#   'Civilian_labor_force_2017': 8084,
#   'Employed_2017': 7610,
#   'Unemployed_2017': 474,
#   'Unemployment_rate_2017': 6,
#   'Civilian_labor_force_2018': 7832,
#   'Employed_2018': 7445,
#   'Unemployed_2018': 387,
#   'Unemployment_rate_2018': 5,
#   'Median_Household_Income_2017.1': 33022},
#  {'id': 17,
#   'Overall Poverty 2017': 6869,
#   'Median_Household_Income_2017': 38059,
#   'POP_ESTIMATE_2017': 33468,
#   'POP_ESTIMATE_2018': 33190,
#   'N_POP_CHG_2017': -236,
#   'N_POP_CHG_2018': -278,
#   'Births_2017': 339,
#   'Births_2018': 322,
#   'Deaths_2017': 437,
#   'Deaths_2018': 466,
#   'INTERNATIONAL_MIG_2017': 12,
#   'INTERNATIONAL_MIG_2018': 14,
#   'DOMESTIC_MIG_2017': -147,
#   'DOMESTIC_MIG_2018': -147,
#   'NET_MIG_2017': -135,
#   'NET_MIG_2018': -133,
#   'R_death_2017': 13,
#   'R_death_2018': 14,
#   'Less than a high school diploma  2013-17': 5045,
#   'High school diploma only  2013-17': 8000,
#   'Some college  associates degree  2013-17': 7704,
#   'Bachelors degree higher  2013-17': 3530,
#   'Percent of adults with less than a high school diploma  2013-17': 21,
#   'Percent of adults with a high school diploma only  2013-17': 33,
#   'Percent of adults completing some college or associates degree  2013-17': 32,
#   'Percent of adults with a bachelors degree or higher  2013-17': 15,
#   'Civilian_labor_force_2017': 14427,
#   'Employed_2017': 13593,
#   'Unemployed_2017': 834,
#   'Unemployment_rate_2017': 6,
#   'Civilian_labor_force_2018': 14418,
#   'Employed_2018': 13659,
#   'Unemployed_2018': 759,
#   'Unemployment_rate_2018': 5,
#   'Median_Household_Income_2017.1': 38059},
#  {'id': 19,
#   'Overall Poverty 2017': 15429,
#   'Median_Household_Income_2017': 56227,
#   'POP_ESTIMATE_2017': 130735,
#   'POP_ESTIMATE_2018': 136744,
#   'N_POP_CHG_2017': 4433,
#   'N_POP_CHG_2018': 6009,
#   'Births_2017': 972,
#   'Births_2018': 983,
#   'Deaths_2017': 1548,
#   'Deaths_2018': 1649,
#   'INTERNATIONAL_MIG_2017': -17,
#   'INTERNATIONAL_MIG_2018': -6,
#   'DOMESTIC_MIG_2017': 4988,
#   'DOMESTIC_MIG_2018': 6620,
#   'NET_MIG_2017': 4971,
#   'NET_MIG_2018': 6614,
#   'R_death_2017': 12,
#   'R_death_2018': 12,
#   'Less than a high school diploma  2013-17': 10385,
#   'High school diploma only  2013-17': 26098,
#   'Some college  associates degree  2013-17': 32147,
#   'Bachelors degree higher  2013-17': 26690,
#   'Percent of adults with less than a high school diploma  2013-17': 11,
#   'Percent of adults with a high school diploma only  2013-17': 27,
#   'Percent of adults completing some college or associates degree  2013-17': 34,
#   'Percent of adults with a bachelors degree or higher  2013-17': 28,
#   'Civilian_labor_force_2017': 51356,
#   'Employed_2017': 48472,
#   'Unemployed_2017': 2884,
#   'Unemployment_rate_2017': 6,
#   'Civilian_labor_force_2018': 52867,
#   'Employed_2018': 50144,
#   'Unemployed_2018': 2723,
#   'Unemployment_rate_2018': 5,
#   'Median_Household_Income_2017.1': 56227},
#  {'id': 21,
#   'Overall Poverty 2017': 28715,
#   'Median_Household_Income_2017': 50271,
#   'POP_ESTIMATE_2017': 257185,
#   'POP_ESTIMATE_2018': 259103,
#   'N_POP_CHG_2017': 2197,
#   'N_POP_CHG_2018': 1918,
#   'Births_2017': 2468,
#   'Births_2018': 2455,
#   'Deaths_2017': 2624,
#   'Deaths_2018': 2668,
#   'INTERNATIONAL_MIG_2017': 184,
#   'INTERNATIONAL_MIG_2018': 194,
#   'DOMESTIC_MIG_2017': 2162,
#   'DOMESTIC_MIG_2018': 1927,
#   'NET_MIG_2017': 2346,
#   'NET_MIG_2018': 2121,
#   'R_death_2017': 10,
#   'R_death_2018': 10,
#   'Less than a high school diploma  2013-17': 16832,
#   'High school diploma only  2013-17': 43888,
#   'Some college  associates degree  2013-17': 52119,
#   'Bachelors degree higher  2013-17': 70716,
#   'Percent of adults with less than a high school diploma  2013-17': 9,
#   'Percent of adults with a high school diploma only  2013-17': 24,
#   'Percent of adults completing some college or associates degree  2013-17': 28,
#   'Percent of adults with a bachelors degree or higher  2013-17': 39,
#   'Civilian_labor_force_2017': 136667,
#   'Employed_2017': 131999,
#   'Unemployed_2017': 4668,
#   'Unemployment_rate_2017': 3,
#   'Civilian_labor_force_2018': 139319,
#   'Employed_2018': 135185,
#   'Unemployed_2018': 4134,
#   'Unemployment_rate_2018': 3,
#   'Median_Household_Income_2017.1': 50271},
#  {'id': 23,
#   'Overall Poverty 2017': 14482,
#   'Median_Household_Income_2017': 42179,
#   'POP_ESTIMATE_2017': 90127,
#   'POP_ESTIMATE_2018': 90382,
#   'N_POP_CHG_2017': 689,
#   'N_POP_CHG_2018': 255,
#   'Births_2017': 910,
#   'Births_2018': 892,
#   'Deaths_2017': 984,
#   'Deaths_2018': 1018,
#   'INTERNATIONAL_MIG_2017': 89,
#   'INTERNATIONAL_MIG_2018': 90,
#   'DOMESTIC_MIG_2017': 677,
#   'DOMESTIC_MIG_2018': 297,
#   'NET_MIG_2017': 766,
#   'NET_MIG_2018': 387,
#   'R_death_2017': 11,
#   'R_death_2018': 11,
#   'Less than a high school diploma  2013-17': 12425,
#   'High school diploma only  2013-17': 19250,
#   'Some college  associates degree  2013-17': 21378,
#   'Bachelors degree higher  2013-17': 10609,
#   'Percent of adults with less than a high school diploma  2013-17': 20,
#   'Percent of adults with a high school diploma only  2013-17': 30,
#   'Percent of adults completing some college or associates degree  2013-17': 34,
#   'Percent of adults with a bachelors degree or higher  2013-17': 17,
#   'Civilian_labor_force_2017': 40517,
#   'Employed_2017': 38834,
#   'Unemployed_2017': 1683,
#   'Unemployment_rate_2017': 4,
#   'Civilian_labor_force_2018': 40579,
#   'Employed_2018': 39133,
#   'Unemployed_2018': 1446,
#   'Unemployment_rate_2018': 4,
#   'Median_Household_Income_2017.1': 42179},
#  {'id': 25,
#   'Overall Poverty 2017': 22816,
#   'Median_Household_Income_2017': 62167,
#   'POP_ESTIMATE_2017': 206724,
#   'POP_ESTIMATE_2018': 211342,
#   'N_POP_CHG_2017': 5254,
#   'N_POP_CHG_2018': 4618,
#   'Births_2017': 2562,
#   'Births_2018': 2551,
#   'Deaths_2017': 1598,
#   'Deaths_2018': 1650,
#   'INTERNATIONAL_MIG_2017': 217,
#   'INTERNATIONAL_MIG_2018': 223,
#   'DOMESTIC_MIG_2017': 4061,
#   'DOMESTIC_MIG_2018': 3487,
#   'NET_MIG_2017': 4278,
#   'NET_MIG_2018': 3710,
#   'R_death_2017': 8,
#   'R_death_2018': 8,
#   'Less than a high school diploma  2013-17': 14059,
#   'High school diploma only  2013-17': 32741,
#   'Some college  associates degree  2013-17': 43895,
#   'Bachelors degree higher  2013-17': 38790,
#   'Percent of adults with less than a high school diploma  2013-17': 11,
#   'Percent of adults with a high school diploma only  2013-17': 25,
#   'Percent of adults completing some college or associates degree  2013-17': 34,
#   'Percent of adults with a bachelors degree or higher  2013-17': 30,
#   'Civilian_labor_force_2017': 104745,
#   'Employed_2017': 100441,
#   'Unemployed_2017': 4304,
#   'Unemployment_rate_2017': 4,
#   'Civilian_labor_force_2018': 106601,
#   'Employed_2018': 102807,
#   'Unemployed_2018': 3794,
#   'Unemployment_rate_2018': 4,
#   'Median_Household_Income_2017.1': 62167},
#  {'id': 27,
#   'Overall Poverty 2017': 13222,
#   'Median_Household_Income_2017': 44798,
#   'POP_ESTIMATE_2017': 81920,
#   'POP_ESTIMATE_2018': 82029,
#   'N_POP_CHG_2017': 153,
#   'N_POP_CHG_2018': 109,
#   'Births_2017': 796,
#   'Births_2018': 787,
#   'Deaths_2017': 971,
#   'Deaths_2018': 965,
#   'INTERNATIONAL_MIG_2017': 68,
#   'INTERNATIONAL_MIG_2018': 68,
#   'DOMESTIC_MIG_2017': 266,
#   'DOMESTIC_MIG_2018': 224,
#   'NET_MIG_2017': 334,
#   'NET_MIG_2018': 292,
#   'R_death_2017': 12,
#   'R_death_2018': 12,
#   'Less than a high school diploma  2013-17': 12471,
#   'High school diploma only  2013-17': 18836,
#   'Some college  associates degree  2013-17': 18561,
#   'Bachelors degree higher  2013-17': 8681,
#   'Percent of adults with less than a high school diploma  2013-17': 21,
#   'Percent of adults with a high school diploma only  2013-17': 32,
#   'Percent of adults completing some college or associates degree  2013-17': 32,
#   'Percent of adults with a bachelors degree or higher  2013-17': 15,
#   'Civilian_labor_force_2017': 36532,
#   'Employed_2017': 34918,
#   'Unemployed_2017': 1614,
#   'Unemployment_rate_2017': 4,
#   'Civilian_labor_force_2018': 36595,
#   'Employed_2018': 35193,
#   'Unemployed_2018': 1402,
#   'Unemployment_rate_2018': 4,
#   'Median_Household_Income_2017.1': 44798},
#  {'id': 29,
#   'Overall Poverty 2017': 848,
#   'Median_Household_Income_2017': 64086,
#   'POP_ESTIMATE_2017': 10561,
#   'POP_ESTIMATE_2018': 10710,
#   'N_POP_CHG_2017': 159,
#   'N_POP_CHG_2018': 149,
#   'Births_2017': 95,
#   'Births_2018': 90,
#   'Deaths_2017': 72,
#   'Deaths_2018': 57,
#   'INTERNATIONAL_MIG_2017': 15,
#   'INTERNATIONAL_MIG_2018': 15,
#   'DOMESTIC_MIG_2017': 124,
#   'DOMESTIC_MIG_2018': 99,
#   'NET_MIG_2017': 139,
#   'NET_MIG_2018': 114,
#   'R_death_2017': 7,
#   'R_death_2018': 5,
#   'Less than a high school diploma  2013-17': 1047,
#   'High school diploma only  2013-17': 1870,
#   'Some college  associates degree  2013-17': 2923,
#   'Bachelors degree higher  2013-17': 1291,
#   'Percent of adults with less than a high school diploma  2013-17': 15,
#   'Percent of adults with a high school diploma only  2013-17': 26,
#   'Percent of adults completing some college or associates degree  2013-17': 41,
#   'Percent of adults with a bachelors degree or higher  2013-17': 18,
#   'Civilian_labor_force_2017': 4731,
#   'Employed_2017': 4526,
#   'Unemployed_2017': 205,
#   'Unemployment_rate_2017': 4,
#   'Civilian_labor_force_2018': 4650,
#   'Employed_2018': 4477,
#   'Unemployed_2018': 173,
#   'Unemployment_rate_2018': 4,
#   'Median_Household_Income_2017.1': 64086},
#  {'id': 31,
#   'Overall Poverty 2017': 9050,
#   'Median_Household_Income_2017': 53192,
#   'POP_ESTIMATE_2017': 68919,
#   'POP_ESTIMATE_2018': 69524,
#   'N_POP_CHG_2017': 108,
#   'N_POP_CHG_2018': 605,
#   'Births_2017': 558,
#   'Births_2018': 529,
#   'Deaths_2017': 817,
#   'Deaths_2018': 882,
#   'INTERNATIONAL_MIG_2017': 43,
#   'INTERNATIONAL_MIG_2018': 29,
#   'DOMESTIC_MIG_2017': 330,
#   'DOMESTIC_MIG_2018': 925,
#   'NET_MIG_2017': 373,
#   'NET_MIG_2018': 954,
#   'R_death_2017': 12,
#   'R_death_2018': 13,
#   'Less than a high school diploma  2013-17': 4721,
#   'High school diploma only  2013-17': 13266,
#   'Some college  associates degree  2013-17': 19831,
#   'Bachelors degree higher  2013-17': 13742,
#   'Percent of adults with less than a high school diploma  2013-17': 9,
#   'Percent of adults with a high school diploma only  2013-17': 26,
#   'Percent of adults completing some college or associates degree  2013-17': 39,
#   'Percent of adults with a bachelors degree or higher  2013-17': 27,
#   'Civilian_labor_force_2017': 31946,
#   'Employed_2017': 30540,
#   'Unemployed_2017': 1406,
#   'Unemployment_rate_2017': 4,
#   'Civilian_labor_force_2018': 31755,
#   'Employed_2018': 30386,
#   'Unemployed_2018': 1369,
#   'Unemployment_rate_2018': 4,
#   'Median_Household_Income_2017.1': 53192},
#  {'id': 33,
#   'Overall Poverty 2017': 4117,
#   'Median_Household_Income_2017': 44998,
#   'POP_ESTIMATE_2017': 22632,
#   'POP_ESTIMATE_2018': 22698,
#   'N_POP_CHG_2017': -133,
#   'N_POP_CHG_2018': 66,
#   'Births_2017': 201,
#   'Births_2018': 197,
#   'Deaths_2017': 290,
#   'Deaths_2018': 243,
#   'INTERNATIONAL_MIG_2017': 15,
#   'INTERNATIONAL_MIG_2018': 15,
#   'DOMESTIC_MIG_2017': -57,
#   'DOMESTIC_MIG_2018': 98,
#   'NET_MIG_2017': -42,
#   'NET_MIG_2018': 113,
#   'R_death_2017': 13,
#   'R_death_2018': 11,
#   'Less than a high school diploma  2013-17': 3729,
#   'High school diploma only  2013-17': 5508,
#   'Some college  associates degree  2013-17': 5102,
#   'Bachelors degree higher  2013-17': 2272,
#   'Percent of adults with less than a high school diploma  2013-17': 22,
#   'Percent of adults with a high school diploma only  2013-17': 33,
#   'Percent of adults completing some college or associates degree  2013-17': 31,
#   'Percent of adults with a bachelors degree or higher  2013-17': 14,
#   'Civilian_labor_force_2017': 9772,
#   'Employed_2017': 9315,
#   'Unemployed_2017': 457,
#   'Unemployment_rate_2017': 5,
#   'Civilian_labor_force_2018': 9820,
#   'Employed_2018': 9391,
#   'Unemployed_2018': 429,
#   'Unemployment_rate_2018': 4,
#   'Median_Household_Income_2017.1': 44998},
#  {'id': 35,
#   'Overall Poverty 2017': 19427,
#   'Median_Household_Income_2017': 53348,
#   'POP_ESTIMATE_2017': 157811,
#   'POP_ESTIMATE_2018': 158652,
#   'N_POP_CHG_2017': 1340,
#   'N_POP_CHG_2018': 841,
#   'Births_2017': 1668,
#   'Births_2018': 1638,
#   'Deaths_2017': 1662,
#   'Deaths_2018': 1682,
#   'INTERNATIONAL_MIG_2017': 221,
#   'INTERNATIONAL_MIG_2018': 223,
#   'DOMESTIC_MIG_2017': 1118,
#   'DOMESTIC_MIG_2018': 666,
#   'NET_MIG_2017': 1339,
#   'NET_MIG_2018': 889,
#   'R_death_2017': 11,
#   'R_death_2018': 11,
#   'Less than a high school diploma  2013-17': 17152,
#   'High school diploma only  2013-17': 32547,
#   'Some college  associates degree  2013-17': 34607,
#   'Bachelors degree higher  2013-17': 23065,
#   'Percent of adults with less than a high school diploma  2013-17': 16,
#   'Percent of adults with a high school diploma only  2013-17': 30,
#   'Percent of adults completing some college or associates degree  2013-17': 32,
#   'Percent of adults with a bachelors degree or higher  2013-17': 22,
#   'Civilian_labor_force_2017': 78689,
#   'Employed_2017': 75451,
#   'Unemployed_2017': 3238,
#   'Unemployment_rate_2017': 4,
#   'Civilian_labor_force_2018': 78802,
#   'Employed_2018': 76041,
#   'Unemployed_2018': 2761,
#   'Unemployment_rate_2018': 4,
#   'Median_Household_Income_2017.1': 53348},
#  {'id': 37,
#   'Overall Poverty 2017': 7305,
#   'Median_Household_Income_2017': 63373,
#   'POP_ESTIMATE_2017': 71248,
#   'POP_ESTIMATE_2018': 73139,
#   'N_POP_CHG_2017': 1602,
#   'N_POP_CHG_2018': 1891,
#   'Births_2017': 644,
#   'Births_2018': 650,
#   'Deaths_2017': 720,
#   'Deaths_2018': 746,
#   'INTERNATIONAL_MIG_2017': -13,
#   'INTERNATIONAL_MIG_2018': -12,
#   'DOMESTIC_MIG_2017': 1686,
#   'DOMESTIC_MIG_2018': 1988,
#   'NET_MIG_2017': 1673,
#   'NET_MIG_2018': 1976,
#   'R_death_2017': 10,
#   'R_death_2018': 10,
#   'Less than a high school diploma  2013-17': 6332,
#   'High school diploma only  2013-17': 10641,
#   'Some college  associates degree  2013-17': 12952,
#   'Bachelors degree higher  2013-17': 20033,
#   'Percent of adults with less than a high school diploma  2013-17': 13,
#   'Percent of adults with a high school diploma only  2013-17': 21,
#   'Percent of adults completing some college or associates degree  2013-17': 26,
#   'Percent of adults with a bachelors degree or higher  2013-17': 40,
#   'Civilian_labor_force_2017': 34182,
#   'Employed_2017': 32868,
#   'Unemployed_2017': 1314,
#   'Unemployment_rate_2017': 4,
#   'Civilian_labor_force_2018': 34637,
#   'Employed_2018': 33479,
#   'Unemployed_2018': 1158,
#   'Unemployment_rate_2018': 3,
#   'Median_Household_Income_2017.1': 63373},
#  {'id': 39,
#   'Overall Poverty 2017': 4760,
#   'Median_Household_Income_2017': 38283,
#   'POP_ESTIMATE_2017': 27980,
#   'POP_ESTIMATE_2018': 28383,
#   'N_POP_CHG_2017': 175,
#   'N_POP_CHG_2018': 403,
#   'Births_2017': 247,
#   'Births_2018': 233,
#   'Deaths_2017': 348,
#   'Deaths_2018': 371,
#   'INTERNATIONAL_MIG_2017': -12,
#   'INTERNATIONAL_MIG_2018': -12,
#   'DOMESTIC_MIG_2017': 288,
#   'DOMESTIC_MIG_2018': 549,
#   'NET_MIG_2017': 276,
#   'NET_MIG_2018': 537,
#   'R_death_2017': 13,
#   'R_death_2018': 13,
#   'Less than a high school diploma  2013-17': 3152,
#   'High school diploma only  2013-17': 7060,
#   'Some college  associates degree  2013-17': 6718,
#   'Bachelors degree higher  2013-17': 4012,
#   'Percent of adults with less than a high school diploma  2013-17': 15,
#   'Percent of adults with a high school diploma only  2013-17': 34,
#   'Percent of adults completing some college or associates degree  2013-17': 32,
#   'Percent of adults with a bachelors degree or higher  2013-17': 19,
#   'Civilian_labor_force_2017': 11180,
#   'Employed_2017': 10628,
#   'Unemployed_2017': 552,
#   'Unemployment_rate_2017': 5,
#   'Civilian_labor_force_2018': 11235,
#   'Employed_2018': 10740,
#   'Unemployed_2018': 495,
#   'Unemployment_rate_2018': 4,
#   'Median_Household_Income_2017.1': 38283},
#  {'id': 41,
#   'Overall Poverty 2017': 2434,
#   'Median_Household_Income_2017': 43182,
#   'POP_ESTIMATE_2017': 14040,
#   'POP_ESTIMATE_2018': 14029,
#   'N_POP_CHG_2017': -161,
#   'N_POP_CHG_2018': -11,
#   'Births_2017': 117,
#   'Births_2018': 118,
#   'Deaths_2017': 179,
#   'Deaths_2018': 193,
#   'INTERNATIONAL_MIG_2017': -5,
#   'INTERNATIONAL_MIG_2018': -5,
#   'DOMESTIC_MIG_2017': -94,
#   'DOMESTIC_MIG_2018': 70,
#   'NET_MIG_2017': -99,
#   'NET_MIG_2018': 65,
#   'R_death_2017': 13,
#   'R_death_2018': 14,
#   'Less than a high school diploma  2013-17': 1685,
#   'High school diploma only  2013-17': 3688,
#   'Some college  associates degree  2013-17': 3130,
#   'Bachelors degree higher  2013-17': 1989,
#   'Percent of adults with less than a high school diploma  2013-17': 16,
#   'Percent of adults with a high school diploma only  2013-17': 35,
#   'Percent of adults completing some college or associates degree  2013-17': 30,
#   'Percent of adults with a bachelors degree or higher  2013-17': 19,
#   'Civilian_labor_force_2017': 5602,
#   'Employed_2017': 5308,
#   'Unemployed_2017': 294,
#   'Unemployment_rate_2017': 5,
#   'Civilian_labor_force_2018': 5582,
#   'Employed_2018': 5335,
#   'Unemployed_2018': 247,
#   'Unemployment_rate_2018': 4,
#   'Median_Household_Income_2017.1': 43182},
#  {'id': 43,
#   'Overall Poverty 2017': 1685,
#   'Median_Household_Income_2017': 43684,
#   'POP_ESTIMATE_2017': 11001,
#   'POP_ESTIMATE_2018': 11139,
#   'N_POP_CHG_2017': 258,
#   'N_POP_CHG_2018': 138,
#   'Births_2017': 106,
#   'Births_2018': 96,
#   'Deaths_2017': 149,
#   'Deaths_2018': 161,
#   'INTERNATIONAL_MIG_2017': -4,
#   'INTERNATIONAL_MIG_2018': -4,
#   'DOMESTIC_MIG_2017': 305,
#   'DOMESTIC_MIG_2018': 207,
#   'NET_MIG_2017': 301,
#   'NET_MIG_2018': 203,
#   'R_death_2017': 14,
#   'R_death_2018': 15,
#   'Less than a high school diploma  2013-17': 886,
#   'High school diploma only  2013-17': 2754,
#   'Some college  associates degree  2013-17': 2679,
#   'Bachelors degree higher  2013-17': 1893,
#   'Percent of adults with less than a high school diploma  2013-17': 11,
#   'Percent of adults with a high school diploma only  2013-17': 34,
#   'Percent of adults completing some college or associates degree  2013-17': 33,
#   'Percent of adults with a bachelors degree or higher  2013-17': 23,
#   'Civilian_labor_force_2017': 3953,
#   'Employed_2017': 3758,
#   'Unemployed_2017': 195,
#   'Unemployment_rate_2017': 5,
#   'Civilian_labor_force_2018': 4111,
#   'Employed_2018': 3933,
#   'Unemployed_2018': 178,
#   'Unemployment_rate_2018': 4,
#   'Median_Household_Income_2017.1': 43684},
#  {'id': 45,
#   'Overall Poverty 2017': 17958,
#   'Median_Household_Income_2017': 39911,
#   'POP_ESTIMATE_2017': 97228,
#   'POP_ESTIMATE_2018': 97645,
#   'N_POP_CHG_2017': 211,
#   'N_POP_CHG_2018': 417,
#   'Births_2017': 1071,
#   'Births_2018': 1038,
#   'Deaths_2017': 1218,
#   'Deaths_2018': 1206,
#   'INTERNATIONAL_MIG_2017': 93,
#   'INTERNATIONAL_MIG_2018': 105,
#   'DOMESTIC_MIG_2017': 271,
#   'DOMESTIC_MIG_2018': 487,
#   'NET_MIG_2017': 364,
#   'NET_MIG_2018': 592,
#   'R_death_2017': 13,
#   'R_death_2018': 12,
#   'Less than a high school diploma  2013-17': 10642,
#   'High school diploma only  2013-17': 23268,
#   'Some college  associates degree  2013-17': 21455,
#   'Bachelors degree higher  2013-17': 10968,
#   'Percent of adults with less than a high school diploma  2013-17': 16,
#   'Percent of adults with a high school diploma only  2013-17': 35,
#   'Percent of adults completing some college or associates degree  2013-17': 32,
#   'Percent of adults with a bachelors degree or higher  2013-17': 17,
#   'Civilian_labor_force_2017': 47509,
#   'Employed_2017': 45330,
#   'Unemployed_2017': 2179,
#   'Unemployment_rate_2017': 5,
#   'Civilian_labor_force_2018': 47966,
#   'Employed_2018': 46071,
#   'Unemployed_2018': 1895,
#   'Unemployment_rate_2018': 4,
#   'Median_Household_Income_2017.1': 39911},
#  {'id': 47,
#   'Overall Poverty 2017': 12220,
#   'Median_Household_Income_2017': 37639,
#   'POP_ESTIMATE_2017': 55987,
#   'POP_ESTIMATE_2018': 55655,
#   'N_POP_CHG_2017': -292,
#   'N_POP_CHG_2018': -332,
#   'Births_2017': 590,
#   'Births_2018': 565,
#   'Deaths_2017': 711,
#   'Deaths_2018': 758,
#   'INTERNATIONAL_MIG_2017': 7,
#   'INTERNATIONAL_MIG_2018': 7,
#   'DOMESTIC_MIG_2017': -174,
#   'DOMESTIC_MIG_2018': -143,
#   'NET_MIG_2017': -167,
#   'NET_MIG_2018': -136,
#   'R_death_2017': 13,
#   'R_death_2018': 14,
#   'Less than a high school diploma  2013-17': 7605,
#   'High school diploma only  2013-17': 12995,
#   'Some college  associates degree  2013-17': 13738,
#   'Bachelors degree higher  2013-17': 4925,
#   'Percent of adults with less than a high school diploma  2013-17': 19,
#   'Percent of adults with a high school diploma only  2013-17': 33,
#   'Percent of adults completing some college or associates degree  2013-17': 35,
#   'Percent of adults with a bachelors degree or higher  2013-17': 13,
#   'Civilian_labor_force_2017': 22296,
#   'Employed_2017': 21089,
#   'Unemployed_2017': 1207,
#   'Unemployment_rate_2017': 5,
#   'Civilian_labor_force_2018': 22338,
#   'Employed_2018': 21223,
#   'Unemployed_2018': 1115,
#   'Unemployment_rate_2018': 5,
#   'Median_Household_Income_2017.1': 37639},
#  {'id': 49,
#   'Overall Poverty 2017': 15942,
#   'Median_Household_Income_2017': 51390,
#   'POP_ESTIMATE_2017': 102754,
#   'POP_ESTIMATE_2018': 102912,
#   'N_POP_CHG_2017': -6,
#   'N_POP_CHG_2018': 158,
#   'Births_2017': 1402,
#   'Births_2018': 1354,
#   'Deaths_2017': 1056,
#   'Deaths_2018': 1008,
#   'INTERNATIONAL_MIG_2017': 95,
#   'INTERNATIONAL_MIG_2018': -24,
#   'DOMESTIC_MIG_2017': -438,
#   'DOMESTIC_MIG_2018': -155,
#   'NET_MIG_2017': -343,
#   'NET_MIG_2018': -179,
#   'R_death_2017': 10,
#   'R_death_2018': 10,
#   'Less than a high school diploma  2013-17': 8281,
#   'High school diploma only  2013-17': 17342,
#   'Some college  associates degree  2013-17': 25189,
#   'Bachelors degree higher  2013-17': 16319,
#   'Percent of adults with less than a high school diploma  2013-17': 12,
#   'Percent of adults with a high school diploma only  2013-17': 26,
#   'Percent of adults completing some college or associates degree  2013-17': 38,
#   'Percent of adults with a bachelors degree or higher  2013-17': 24,
#   'Civilian_labor_force_2017': 41771,
#   'Employed_2017': 39852,
#   'Unemployed_2017': 1919,
#   'Unemployment_rate_2017': 5,
#   'Civilian_labor_force_2018': 41528,
#   'Employed_2018': 39784,
#   'Unemployed_2018': 1744,
#   'Unemployment_rate_2018': 4,
#   'Median_Household_Income_2017.1': 51390},
#  {'id': 51,
#   'Overall Poverty 2017': 58888,
#   'Median_Household_Income_2017': 44065,
#   'POP_ESTIMATE_2017': 331239,
#   'POP_ESTIMATE_2018': 332330,
#   'N_POP_CHG_2017': -2061,
#   'N_POP_CHG_2018': 1091,
#   'Births_2017': 5448,
#   'Births_2018': 5298,
#   'Deaths_2017': 2565,
#   'Deaths_2018': 2645,
#   'INTERNATIONAL_MIG_2017': 788,
#   'INTERNATIONAL_MIG_2018': 511,
#   'DOMESTIC_MIG_2017': -5760,
#   'DOMESTIC_MIG_2018': -2065,
#   'NET_MIG_2017': -4972,
#   'NET_MIG_2018': -1554,
#   'R_death_2017': 8,
#   'R_death_2018': 8,
#   'Less than a high school diploma  2013-17': 19437,
#   'High school diploma only  2013-17': 52895,
#   'Some college  associates degree  2013-17': 82177,
#   'Bachelors degree higher  2013-17': 49477,
#   'Percent of adults with less than a high school diploma  2013-17': 10,
#   'Percent of adults with a high school diploma only  2013-17': 26,
#   'Percent of adults completing some college or associates degree  2013-17': 40,
#   'Percent of adults with a bachelors degree or higher  2013-17': 24,
#   'Civilian_labor_force_2017': 127751,
#   'Employed_2017': 120477,
#   'Unemployed_2017': 7274,
#   'Unemployment_rate_2017': 6,
#   'Civilian_labor_force_2018': 127957,
#   'Employed_2018': 121379,
#   'Unemployed_2018': 6578,
#   'Unemployment_rate_2018': 5,
#   'Median_Household_Income_2017.1': 44065},
#  {'id': 53,
#   'Overall Poverty 2017': 2785,
#   'Median_Household_Income_2017': 62397,
#   'POP_ESTIMATE_2017': 26323,
#   'POP_ESTIMATE_2018': 27072,
#   'N_POP_CHG_2017': 669,
#   'N_POP_CHG_2018': 749,
#   'Births_2017': 256,
#   'Births_2018': 269,
#   'Deaths_2017': 216,
#   'Deaths_2018': 235,
#   'INTERNATIONAL_MIG_2017': 7,
#   'INTERNATIONAL_MIG_2018': 11,
#   'DOMESTIC_MIG_2017': 620,
#   'DOMESTIC_MIG_2018': 701,
#   'NET_MIG_2017': 627,
#   'NET_MIG_2018': 712,
#   'R_death_2017': 8,
#   'R_death_2018': 9,
#   'Less than a high school diploma  2013-17': 2223,
#   'High school diploma only  2013-17': 5072,
#   'Some college  associates degree  2013-17': 6475,
#   'Bachelors degree higher  2013-17': 4091,
#   'Percent of adults with less than a high school diploma  2013-17': 12,
#   'Percent of adults with a high school diploma only  2013-17': 28,
#   'Percent of adults completing some college or associates degree  2013-17': 36,
#   'Percent of adults with a bachelors degree or higher  2013-17': 23,
#   'Civilian_labor_force_2017': 13588,
#   'Employed_2017': 13002,
#   'Unemployed_2017': 586,
#   'Unemployment_rate_2017': 4,
#   'Civilian_labor_force_2018': 13633,
#   'Employed_2018': 13141,
#   'Unemployed_2018': 492,
#   'Unemployment_rate_2018': 4,
#   'Median_Household_Income_2017.1': 62397},
#  {'id': 55,
#   'Overall Poverty 2017': 3364,
#   'Median_Household_Income_2017': 57316,
#   'POP_ESTIMATE_2017': 36115,
#   'POP_ESTIMATE_2018': 36501,
#   'N_POP_CHG_2017': 350,
#   'N_POP_CHG_2018': 386,
#   'Births_2017': 326,
#   'Births_2018': 317,
#   'Deaths_2017': 353,
#   'Deaths_2018': 351,
#   'INTERNATIONAL_MIG_2017': 14,
#   'INTERNATIONAL_MIG_2018': 17,
#   'DOMESTIC_MIG_2017': 363,
#   'DOMESTIC_MIG_2018': 402,
#   'NET_MIG_2017': 377,
#   'NET_MIG_2018': 419,
#   'R_death_2017': 10,
#   'R_death_2018': 10,
#   'Less than a high school diploma  2013-17': 1800,
#   'High school diploma only  2013-17': 6710,
#   'Some college  associates degree  2013-17': 9931,
#   'Bachelors degree higher  2013-17': 7841,
#   'Percent of adults with less than a high school diploma  2013-17': 7,
#   'Percent of adults with a high school diploma only  2013-17': 26,
#   'Percent of adults completing some college or associates degree  2013-17': 38,
#   'Percent of adults with a bachelors degree or higher  2013-17': 30,
#   'Civilian_labor_force_2017': 20121,
#   'Employed_2017': 18943,
#   'Unemployed_2017': 1178,
#   'Unemployment_rate_2017': 6,
#   'Civilian_labor_force_2018': 19851,
#   'Employed_2018': 18836,
#   'Unemployed_2018': 1015,
#   'Unemployment_rate_2018': 5,
#   'Median_Household_Income_2017.1': 57316},
#  {'id': 57,
#   'Overall Poverty 2017': 24941,
#   'Median_Household_Income_2017': 47595,
#   'POP_ESTIMATE_2017': 165313,
#   'POP_ESTIMATE_2018': 166614,
#   'N_POP_CHG_2017': 919,
#   'N_POP_CHG_2018': 1301,
#   'Births_2017': 1778,
#   'Births_2018': 1733,
#   'Deaths_2017': 1806,
#   'Deaths_2018': 1796,
#   'INTERNATIONAL_MIG_2017': 58,
#   'INTERNATIONAL_MIG_2018': 68,
#   'DOMESTIC_MIG_2017': 895,
#   'DOMESTIC_MIG_2018': 1302,
#   'NET_MIG_2017': 953,
#   'NET_MIG_2018': 1370,
#   'R_death_2017': 11,
#   'R_death_2018': 11,
#   'Less than a high school diploma  2013-17': 19010,
#   'High school diploma only  2013-17': 38447,
#   'Some college  associates degree  2013-17': 36305,
#   'Bachelors degree higher  2013-17': 20666,
#   'Percent of adults with less than a high school diploma  2013-17': 17,
#   'Percent of adults with a high school diploma only  2013-17': 34,
#   'Percent of adults completing some college or associates degree  2013-17': 32,
#   'Percent of adults with a bachelors degree or higher  2013-17': 18,
#   'Civilian_labor_force_2017': 79670,
#   'Employed_2017': 76274,
#   'Unemployed_2017': 3396,
#   'Unemployment_rate_2017': 4,
#   'Civilian_labor_force_2018': 80112,
#   'Employed_2018': 77186,
#   'Unemployed_2018': 2926,
#   'Unemployment_rate_2018': 4,
#   'Median_Household_Income_2017.1': 47595},
#  {'id': 59,
#   'Overall Poverty 2017': 5117,
#   'Median_Household_Income_2017': 58147,
#   'POP_ESTIMATE_2017': 42369,
#   'POP_ESTIMATE_2018': 42733,
#   'N_POP_CHG_2017': 436,
#   'N_POP_CHG_2018': 364,
#   'Births_2017': 386,
#   'Births_2018': 398,
#   'Deaths_2017': 440,
#   'Deaths_2018': 387,
#   'INTERNATIONAL_MIG_2017': 7,
#   'INTERNATIONAL_MIG_2018': 8,
#   'DOMESTIC_MIG_2017': 483,
#   'DOMESTIC_MIG_2018': 347,
#   'NET_MIG_2017': 490,
#   'NET_MIG_2018': 355,
#   'R_death_2017': 10,
#   'R_death_2018': 9,
#   'Less than a high school diploma  2013-17': 3784,
#   'High school diploma only  2013-17': 9371,
#   'Some college  associates degree  2013-17': 9733,
#   'Bachelors degree higher  2013-17': 6821,
#   'Percent of adults with less than a high school diploma  2013-17': 13,
#   'Percent of adults with a high school diploma only  2013-17': 32,
#   'Percent of adults completing some college or associates degree  2013-17': 33,
#   'Percent of adults with a bachelors degree or higher  2013-17': 23,
#   'Civilian_labor_force_2017': 20355,
#   'Employed_2017': 19551,
#   'Unemployed_2017': 804,
#   'Unemployment_rate_2017': 4,
#   'Civilian_labor_force_2018': 20474,
#   'Employed_2018': 19774,
#   'Unemployed_2018': 700,
#   'Unemployment_rate_2018': 3,
#   'Median_Household_Income_2017.1': 58147},
#  {'id': 61,
#   'Overall Poverty 2017': 12119,
#   'Median_Household_Income_2017': 39470,
#   'POP_ESTIMATE_2017': 58862,
#   'POP_ESTIMATE_2018': 58856,
#   'N_POP_CHG_2017': -398,
#   'N_POP_CHG_2018': -6,
#   'Births_2017': 697,
#   'Births_2018': 645,
#   'Deaths_2017': 551,
#   'Deaths_2018': 576,
#   'INTERNATIONAL_MIG_2017': 109,
#   'INTERNATIONAL_MIG_2018': 114,
#   'DOMESTIC_MIG_2017': -653,
#   'DOMESTIC_MIG_2018': -188,
#   'NET_MIG_2017': -544,
#   'NET_MIG_2018': -74,
#   'R_death_2017': 9,
#   'R_death_2018': 10,
#   'Less than a high school diploma  2013-17': 10623,
#   'High school diploma only  2013-17': 13017,
#   'Some college  associates degree  2013-17': 11906,
#   'Bachelors degree higher  2013-17': 4283,
#   'Percent of adults with less than a high school diploma  2013-17': 27,
#   'Percent of adults with a high school diploma only  2013-17': 33,
#   'Percent of adults completing some college or associates degree  2013-17': 30,
#   'Percent of adults with a bachelors degree or higher  2013-17': 11,
#   'Civilian_labor_force_2017': 25466,
#   'Employed_2017': 24239,
#   'Unemployed_2017': 1227,
#   'Unemployment_rate_2017': 5,
#   'Civilian_labor_force_2018': 24946,
#   'Employed_2018': 23866,
#   'Unemployed_2018': 1080,
#   'Unemployment_rate_2018': 4,
#   'Median_Household_Income_2017.1': 39470},
#  {'id': 63,
#   'Overall Poverty 2017': 47090,
#   'Median_Household_Income_2017': 60045,
#   'POP_ESTIMATE_2017': 311888,
#   'POP_ESTIMATE_2018': 316739,
#   'N_POP_CHG_2017': 4183,
#   'N_POP_CHG_2018': 4851,
#   'Births_2017': 4257,
#   'Births_2018': 4209,
#   'Deaths_2017': 2096,
#   'Deaths_2018': 2204,
#   'INTERNATIONAL_MIG_2017': 1810,
#   'INTERNATIONAL_MIG_2018': 1827,
#   'DOMESTIC_MIG_2017': 218,
#   'DOMESTIC_MIG_2018': 1012,
#   'NET_MIG_2017': 2028,
#   'NET_MIG_2018': 2839,
#   'R_death_2017': 7,
#   'R_death_2018': 7,
#   'Less than a high school diploma  2013-17': 25103,
#   'High school diploma only  2013-17': 34867,
#   'Some college  associates degree  2013-17': 48093,
#   'Bachelors degree higher  2013-17': 96799,
#   'Percent of adults with less than a high school diploma  2013-17': 12,
#   'Percent of adults with a high school diploma only  2013-17': 17,
#   'Percent of adults completing some college or associates degree  2013-17': 24,
#   'Percent of adults with a bachelors degree or higher  2013-17': 47,
#   'Civilian_labor_force_2017': 165334,
#   'Employed_2017': 158702,
#   'Unemployed_2017': 6632,
#   'Unemployment_rate_2017': 4,
#   'Civilian_labor_force_2018': 167606,
#   'Employed_2018': 161771,
#   'Unemployed_2018': 5835,
#   'Unemployment_rate_2018': 4,
#   'Median_Household_Income_2017.1': 60045},
#  {'id': 65,
#   'Overall Poverty 2017': 13222,
#   'Median_Household_Income_2017': 35130,
#   'POP_ESTIMATE_2017': 52757,
#   'POP_ESTIMATE_2018': 52005,
#   'N_POP_CHG_2017': -520,
#   'N_POP_CHG_2018': -752,
#   'Births_2017': 598,
#   'Births_2018': 571,
#   'Deaths_2017': 647,
#   'Deaths_2018': 630,
#   'INTERNATIONAL_MIG_2017': 3,
#   'INTERNATIONAL_MIG_2018': 3,
#   'DOMESTIC_MIG_2017': -475,
#   'DOMESTIC_MIG_2018': -696,
#   'NET_MIG_2017': -472,
#   'NET_MIG_2018': -693,
#   'R_death_2017': 12,
#   'R_death_2018': 12,
#   'Less than a high school diploma  2013-17': 7879,
#   'High school diploma only  2013-17': 13599,
#   'Some college  associates degree  2013-17': 10975,
#   'Bachelors degree higher  2013-17': 4264,
#   'Percent of adults with less than a high school diploma  2013-17': 22,
#   'Percent of adults with a high school diploma only  2013-17': 37,
#   'Percent of adults completing some college or associates degree  2013-17': 30,
#   'Percent of adults with a bachelors degree or higher  2013-17': 12,
#   'Civilian_labor_force_2017': 21947,
#   'Employed_2017': 20272,
#   'Unemployed_2017': 1675,
#   'Unemployment_rate_2017': 8,
#   'Civilian_labor_force_2018': 21741,
#   'Employed_2018': 20271,
#   'Unemployed_2018': 1470,
#   'Unemployment_rate_2018': 7,
#   'Median_Household_Income_2017.1': 35130},
#  {'id': 67,
#   'Overall Poverty 2017': 60638,
#   'Median_Household_Income_2017': 50803,
#   'POP_ESTIMATE_2017': 375724,
#   'POP_ESTIMATE_2018': 379099,
#   'N_POP_CHG_2017': 4567,
#   'N_POP_CHG_2018': 3375,
#   'Births_2017': 4455,
#   'Births_2018': 4399,
#   'Deaths_2017': 3290,
#   'Deaths_2018': 3284,
#   'INTERNATIONAL_MIG_2017': 494,
#   'INTERNATIONAL_MIG_2018': 555,
#   'DOMESTIC_MIG_2017': 2906,
#   'DOMESTIC_MIG_2018': 1711,
#   'NET_MIG_2017': 3400,
#   'NET_MIG_2018': 2266,
#   'R_death_2017': 9,
#   'R_death_2018': 9,
#   'Less than a high school diploma  2013-17': 28193,
#   'High school diploma only  2013-17': 62094,
#   'Some college  associates degree  2013-17': 72144,
#   'Bachelors degree higher  2013-17': 82982,
#   'Percent of adults with less than a high school diploma  2013-17': 12,
#   'Percent of adults with a high school diploma only  2013-17': 25,
#   'Percent of adults completing some college or associates degree  2013-17': 29,
#   'Percent of adults with a bachelors degree or higher  2013-17': 34,
#   'Civilian_labor_force_2017': 184877,
#   'Employed_2017': 176872,
#   'Unemployed_2017': 8005,
#   'Unemployment_rate_2017': 4,
#   'Civilian_labor_force_2018': 186122,
#   'Employed_2018': 179013,
#   'Unemployed_2018': 7109,
#   'Unemployment_rate_2018': 4,
#   'Median_Household_Income_2017.1': 50803},
#  {'id': 69,
#   'Overall Poverty 2017': 10129,
#   'Median_Household_Income_2017': 53076,
#   'POP_ESTIMATE_2017': 66033,
#   'POP_ESTIMATE_2018': 67560,
#   'N_POP_CHG_2017': 1437,
#   'N_POP_CHG_2018': 1527,
#   'Births_2017': 697,
#   'Births_2018': 703,
#   'Deaths_2017': 595,
#   'Deaths_2018': 612,
#   'INTERNATIONAL_MIG_2017': 46,
#   'INTERNATIONAL_MIG_2018': 46,
#   'DOMESTIC_MIG_2017': 1285,
#   'DOMESTIC_MIG_2018': 1382,
#   'NET_MIG_2017': 1331,
#   'NET_MIG_2018': 1428,
#   'R_death_2017': 9,
#   'R_death_2018': 9,
#   'Less than a high school diploma  2013-17': 6921,
#   'High school diploma only  2013-17': 13167,
#   'Some college  associates degree  2013-17': 14526,
#   'Bachelors degree higher  2013-17': 9212,
#   'Percent of adults with less than a high school diploma  2013-17': 16,
#   'Percent of adults with a high school diploma only  2013-17': 30,
#   'Percent of adults completing some college or associates degree  2013-17': 33,
#   'Percent of adults with a bachelors degree or higher  2013-17': 21,
#   'Civilian_labor_force_2017': 30123,
#   'Employed_2017': 28730,
#   'Unemployed_2017': 1393,
#   'Unemployment_rate_2017': 5,
#   'Civilian_labor_force_2018': 30642,
#   'Employed_2018': 29421,
#   'Unemployed_2018': 1221,
#   'Unemployment_rate_2018': 4,
#   'Median_Household_Income_2017.1': 53076},
#  {'id': 71,
#   'Overall Poverty 2017': 32751,
#   'Median_Household_Income_2017': 50016,
#   'POP_ESTIMATE_2017': 219819,
#   'POP_ESTIMATE_2018': 222846,
#   'N_POP_CHG_2017': 3103,
#   'N_POP_CHG_2018': 3027,
#   'Births_2017': 2517,
#   'Births_2018': 2545,
#   'Deaths_2017': 2331,
#   'Deaths_2018': 2379,
#   'INTERNATIONAL_MIG_2017': 140,
#   'INTERNATIONAL_MIG_2018': 149,
#   'DOMESTIC_MIG_2017': 2769,
#   'DOMESTIC_MIG_2018': 2707,
#   'NET_MIG_2017': 2909,
#   'NET_MIG_2018': 2856,
#   'R_death_2017': 11,
#   'R_death_2018': 11,
#   'Less than a high school diploma  2013-17': 23424,
#   'High school diploma only  2013-17': 45116,
#   'Some college  associates degree  2013-17': 48281,
#   'Bachelors degree higher  2013-17': 30064,
#   'Percent of adults with less than a high school diploma  2013-17': 16,
#   'Percent of adults with a high school diploma only  2013-17': 31,
#   'Percent of adults completing some college or associates degree  2013-17': 33,
#   'Percent of adults with a bachelors degree or higher  2013-17': 21,
#   'Civilian_labor_force_2017': 107847,
#   'Employed_2017': 102905,
#   'Unemployed_2017': 4942,
#   'Unemployment_rate_2017': 5,
#   'Civilian_labor_force_2018': 109604,
#   'Employed_2018': 105359,
#   'Unemployed_2018': 4245,
#   'Unemployment_rate_2018': 4,
#   'Median_Household_Income_2017.1': 50016},
#  {'id': 73,
#   'Overall Poverty 2017': 1802,
#   'Median_Household_Income_2017': 50164,
#   'POP_ESTIMATE_2017': 11515,
#   'POP_ESTIMATE_2018': 11573,
#   'N_POP_CHG_2017': -52,
#   'N_POP_CHG_2018': 58,
#   'Births_2017': 105,
#   'Births_2018': 103,
#   'Deaths_2017': 122,
#   'Deaths_2018': 142,
#   'INTERNATIONAL_MIG_2017': 9,
#   'INTERNATIONAL_MIG_2018': 9,
#   'DOMESTIC_MIG_2017': -42,
#   'DOMESTIC_MIG_2018': 86,
#   'NET_MIG_2017': -33,
#   'NET_MIG_2018': 95,
#   'R_death_2017': 11,
#   'R_death_2018': 12,
#   'Less than a high school diploma  2013-17': 1158,
#   'High school diploma only  2013-17': 2956,
#   'Some college  associates degree  2013-17': 2862,
#   'Bachelors degree higher  2013-17': 1301,
#   'Percent of adults with less than a high school diploma  2013-17': 14,
#   'Percent of adults with a high school diploma only  2013-17': 36,
#   'Percent of adults completing some college or associates degree  2013-17': 35,
#   'Percent of adults with a bachelors degree or higher  2013-17': 16,
#   'Civilian_labor_force_2017': 5283,
#   'Employed_2017': 5051,
#   'Unemployed_2017': 232,
#   'Unemployment_rate_2017': 4,
#   'Civilian_labor_force_2018': 5309,
#   'Employed_2018': 5097,
#   'Unemployed_2018': 212,
#   'Unemployment_rate_2018': 4,
#   'Median_Household_Income_2017.1': 50164},
#  {'id': 75,
#   'Overall Poverty 2017': 1518,
#   'Median_Household_Income_2017': 37748,
#   'POP_ESTIMATE_2017': 8534,
#   'POP_ESTIMATE_2018': 8484,
#   'N_POP_CHG_2017': -11,
#   'N_POP_CHG_2018': -50,
#   'Births_2017': 86,
#   'Births_2018': 76,
#   'Deaths_2017': 104,
#   'Deaths_2018': 98,
#   'INTERNATIONAL_MIG_2017': -1,
#   'INTERNATIONAL_MIG_2018': -1,
#   'DOMESTIC_MIG_2017': 9,
#   'DOMESTIC_MIG_2018': -26,
#   'NET_MIG_2017': 8,
#   'NET_MIG_2018': -27,
#   'R_death_2017': 12,
#   'R_death_2018': 12,
#   'Less than a high school diploma  2013-17': 1101,
#   'High school diploma only  2013-17': 2260,
#   'Some college  associates degree  2013-17': 1835,
#   'Bachelors degree higher  2013-17': 857,
#   'Percent of adults with less than a high school diploma  2013-17': 18,
#   'Percent of adults with a high school diploma only  2013-17': 37,
#   'Percent of adults completing some college or associates degree  2013-17': 30,
#   'Percent of adults with a bachelors degree or higher  2013-17': 14,
# ...
#   'High school diploma only  2013-17': 6796,
#   'Some college  associates degree  2013-17': 7607,
#   'Bachelors degree higher  2013-17': 7482,
#   'Percent of adults with less than a high school diploma  2013-17': 13,
#   'Percent of adults with a high school diploma only  2013-17': 27,
#   'Percent of adults completing some college or associates degree  2013-17': 30,
#   'Percent of adults with a bachelors degree or higher  2013-17': 30,
#   'Civilian_labor_force_2017': 14222,
#   'Employed_2017': 13614,
#   'Unemployed_2017': 608,
#   'Unemployment_rate_2017': 4,
#   'Civilian_labor_force_2018': 14275,
#   'Employed_2018': 13737,
#   'Unemployed_2018': 538,
#   'Unemployment_rate_2018': 4,
#   'Median_Household_Income_2017.1': 47587},
#  {'id': 177,
#   'Overall Poverty 2017': 870,
#   'Median_Household_Income_2017': 35223,
#   'POP_ESTIMATE_2017': 4183,
#   'POP_ESTIMATE_2018': 4131,
#   'N_POP_CHG_2017': 158,
#   'N_POP_CHG_2018': -52,
#   'Births_2017': 44,
#   'Births_2018': 44,
#   'Deaths_2017': 40,
#   'Deaths_2018': 53,
#   'INTERNATIONAL_MIG_2017': 2,
#   'INTERNATIONAL_MIG_2018': 2,
#   'DOMESTIC_MIG_2017': 150,
#   'DOMESTIC_MIG_2018': -45,
#   'NET_MIG_2017': 152,
#   'NET_MIG_2018': -43,
#   'R_death_2017': 10,
#   'R_death_2018': 13,
#   'Less than a high school diploma  2013-17': 821,
#   'High school diploma only  2013-17': 1342,
#   'Some college  associates degree  2013-17': 805,
#   'Bachelors degree higher  2013-17': 245,
#   'Percent of adults with less than a high school diploma  2013-17': 26,
#   'Percent of adults with a high school diploma only  2013-17': 42,
#   'Percent of adults completing some college or associates degree  2013-17': 25,
#   'Percent of adults with a bachelors degree or higher  2013-17': 8,
#   'Civilian_labor_force_2017': 1495,
#   'Employed_2017': 1381,
#   'Unemployed_2017': 114,
#   'Unemployment_rate_2017': 8,
#   'Civilian_labor_force_2018': 1457,
#   'Employed_2018': 1365,
#   'Unemployed_2018': 92,
#   'Unemployment_rate_2018': 6,
#   'Median_Household_Income_2017.1': 35223},
#  {'id': 179,
#   'Overall Poverty 2017': 20824,
#   'Median_Household_Income_2017': 77875,
#   'POP_ESTIMATE_2017': 231424,
#   'POP_ESTIMATE_2018': 235908,
#   'N_POP_CHG_2017': 5041,
#   'N_POP_CHG_2018': 4484,
#   'Births_2017': 2390,
#   'Births_2018': 2396,
#   'Deaths_2017': 1511,
#   'Deaths_2018': 1466,
#   'INTERNATIONAL_MIG_2017': 128,
#   'INTERNATIONAL_MIG_2018': 140,
#   'DOMESTIC_MIG_2017': 4034,
#   'DOMESTIC_MIG_2018': 3425,
#   'NET_MIG_2017': 4162,
#   'NET_MIG_2018': 3565,
#   'R_death_2017': 7,
#   'R_death_2018': 6,
#   'Less than a high school diploma  2013-17': 14396,
#   'High school diploma only  2013-17': 35519,
#   'Some college  associates degree  2013-17': 42945,
#   'Bachelors degree higher  2013-17': 47757,
#   'Percent of adults with less than a high school diploma  2013-17': 10,
#   'Percent of adults with a high school diploma only  2013-17': 25,
#   'Percent of adults completing some college or associates degree  2013-17': 31,
#   'Percent of adults with a bachelors degree or higher  2013-17': 34,
#   'Civilian_labor_force_2017': 119170,
#   'Employed_2017': 114437,
#   'Unemployed_2017': 4733,
#   'Unemployment_rate_2017': 4,
#   'Civilian_labor_force_2018': 121250,
#   'Employed_2018': 117099,
#   'Unemployed_2018': 4151,
#   'Unemployment_rate_2018': 3,
#   'Median_Household_Income_2017.1': 77875},
#  {'id': 181,
#   'Overall Poverty 2017': 10217,
#   'Median_Household_Income_2017': 39847,
#   'POP_ESTIMATE_2017': 44312,
#   'POP_ESTIMATE_2018': 44582,
#   'N_POP_CHG_2017': -188,
#   'N_POP_CHG_2018': 270,
#   'Births_2017': 565,
#   'Births_2018': 541,
#   'Deaths_2017': 532,
#   'Deaths_2018': 535,
#   'INTERNATIONAL_MIG_2017': 33,
#   'INTERNATIONAL_MIG_2018': 35,
#   'DOMESTIC_MIG_2017': -253,
#   'DOMESTIC_MIG_2018': 232,
#   'NET_MIG_2017': -220,
#   'NET_MIG_2018': 267,
#   'R_death_2017': 12,
#   'R_death_2018': 12,
#   'Less than a high school diploma  2013-17': 6488,
#   'High school diploma only  2013-17': 11079,
#   'Some college  associates degree  2013-17': 8579,
#   'Bachelors degree higher  2013-17': 3592,
#   'Percent of adults with less than a high school diploma  2013-17': 22,
#   'Percent of adults with a high school diploma only  2013-17': 37,
#   'Percent of adults completing some college or associates degree  2013-17': 29,
#   'Percent of adults with a bachelors degree or higher  2013-17': 12,
#   'Civilian_labor_force_2017': 17896,
#   'Employed_2017': 16795,
#   'Unemployed_2017': 1101,
#   'Unemployment_rate_2017': 6,
#   'Civilian_labor_force_2018': 17444,
#   'Employed_2018': 16441,
#   'Unemployed_2018': 1003,
#   'Unemployment_rate_2018': 6,
#   'Median_Household_Income_2017.1': 39847},
#  {'id': 183,
#   'Overall Poverty 2017': 93924,
#   'Median_Household_Income_2017': 77641,
#   'POP_ESTIMATE_2017': 1071886,
#   'POP_ESTIMATE_2018': 1092305,
#   'N_POP_CHG_2017': 23505,
#   'N_POP_CHG_2018': 20419,
#   'Births_2017': 12827,
#   'Births_2018': 12787,
#   'Deaths_2017': 5833,
#   'Deaths_2018': 6042,
#   'INTERNATIONAL_MIG_2017': 4474,
#   'INTERNATIONAL_MIG_2018': 4521,
#   'DOMESTIC_MIG_2017': 11987,
#   'DOMESTIC_MIG_2018': 9136,
#   'NET_MIG_2017': 16461,
#   'NET_MIG_2018': 13657,
#   'R_death_2017': 6,
#   'R_death_2018': 6,
#   'Less than a high school diploma  2013-17': 51062,
#   'High school diploma only  2013-17': 107031,
#   'Some college  associates degree  2013-17': 173905,
#   'Bachelors degree higher  2013-17': 345121,
#   'Percent of adults with less than a high school diploma  2013-17': 8,
#   'Percent of adults with a high school diploma only  2013-17': 16,
#   'Percent of adults completing some college or associates degree  2013-17': 26,
#   'Percent of adults with a bachelors degree or higher  2013-17': 51,
#   'Civilian_labor_force_2017': 573624,
#   'Employed_2017': 551418,
#   'Unemployed_2017': 22206,
#   'Unemployment_rate_2017': 4,
#   'Civilian_labor_force_2018': 584548,
#   'Employed_2018': 564962,
#   'Unemployed_2018': 19586,
#   'Unemployment_rate_2018': 3,
#   'Median_Household_Income_2017.1': 77641},
#  {'id': 185,
#   'Overall Poverty 2017': 3966,
#   'Median_Household_Income_2017': 36831,
#   'POP_ESTIMATE_2017': 19869,
#   'POP_ESTIMATE_2018': 19807,
#   'N_POP_CHG_2017': -23,
#   'N_POP_CHG_2018': -62,
#   'Births_2017': 187,
#   'Births_2018': 175,
#   'Deaths_2017': 282,
#   'Deaths_2018': 266,
#   'INTERNATIONAL_MIG_2017': -3,
#   'INTERNATIONAL_MIG_2018': -2,
#   'DOMESTIC_MIG_2017': 77,
#   'DOMESTIC_MIG_2018': 33,
#   'NET_MIG_2017': 74,
#   'NET_MIG_2018': 31,
#   'R_death_2017': 14,
#   'R_death_2018': 13,
#   'Less than a high school diploma  2013-17': 2882,
#   'High school diploma only  2013-17': 5008,
#   'Some college  associates degree  2013-17': 4298,
#   'Bachelors degree higher  2013-17': 2280,
#   'Percent of adults with less than a high school diploma  2013-17': 20,
#   'Percent of adults with a high school diploma only  2013-17': 35,
#   'Percent of adults completing some college or associates degree  2013-17': 30,
#   'Percent of adults with a bachelors degree or higher  2013-17': 16,
#   'Civilian_labor_force_2017': 6827,
#   'Employed_2017': 6364,
#   'Unemployed_2017': 463,
#   'Unemployment_rate_2017': 7,
#   'Civilian_labor_force_2018': 6574,
#   'Employed_2018': 6183,
#   'Unemployed_2018': 391,
#   'Unemployment_rate_2018': 6,
#   'Median_Household_Income_2017.1': 36831},
#  {'id': 187,
#   'Overall Poverty 2017': 2947,
#   'Median_Household_Income_2017': 36171,
#   'POP_ESTIMATE_2017': 12019,
#   'POP_ESTIMATE_2018': 11859,
#   'N_POP_CHG_2017': -103,
#   'N_POP_CHG_2018': -160,
#   'Births_2017': 128,
#   'Births_2018': 126,
#   'Deaths_2017': 152,
#   'Deaths_2018': 159,
#   'INTERNATIONAL_MIG_2017': 11,
#   'INTERNATIONAL_MIG_2018': 10,
#   'DOMESTIC_MIG_2017': -91,
#   'DOMESTIC_MIG_2018': -136,
#   'NET_MIG_2017': -80,
#   'NET_MIG_2018': -126,
#   'R_death_2017': 13,
#   'R_death_2018': 13,
#   'Less than a high school diploma  2013-17': 1925,
#   'High school diploma only  2013-17': 3062,
#   'Some college  associates degree  2013-17': 2751,
#   'Bachelors degree higher  2013-17': 778,
#   'Percent of adults with less than a high school diploma  2013-17': 23,
#   'Percent of adults with a high school diploma only  2013-17': 36,
#   'Percent of adults completing some college or associates degree  2013-17': 32,
#   'Percent of adults with a bachelors degree or higher  2013-17': 9,
#   'Civilian_labor_force_2017': 4772,
#   'Employed_2017': 4460,
#   'Unemployed_2017': 312,
#   'Unemployment_rate_2017': 7,
#   'Civilian_labor_force_2018': 4628,
#   'Employed_2018': 4353,
#   'Unemployed_2018': 275,
#   'Unemployment_rate_2018': 6,
#   'Median_Household_Income_2017.1': 36171},
#  {'id': 189,
#   'Overall Poverty 2017': 10129,
#   'Median_Household_Income_2017': 48417,
#   'POP_ESTIMATE_2017': 55088,
#   'POP_ESTIMATE_2018': 55945,
#   'N_POP_CHG_2017': 993,
#   'N_POP_CHG_2018': 857,
#   'Births_2017': 369,
#   'Births_2018': 381,
#   'Deaths_2017': 374,
#   'Deaths_2018': 398,
#   'INTERNATIONAL_MIG_2017': 24,
#   'INTERNATIONAL_MIG_2018': 23,
#   'DOMESTIC_MIG_2017': 966,
#   'DOMESTIC_MIG_2018': 842,
#   'NET_MIG_2017': 990,
#   'NET_MIG_2018': 865,
#   'R_death_2017': 7,
#   'R_death_2018': 7,
#   'Less than a high school diploma  2013-17': 3442,
#   'High school diploma only  2013-17': 5988,
#   'Some college  associates degree  2013-17': 8170,
#   'Bachelors degree higher  2013-17': 12571,
#   'Percent of adults with less than a high school diploma  2013-17': 11,
#   'Percent of adults with a high school diploma only  2013-17': 20,
#   'Percent of adults completing some college or associates degree  2013-17': 27,
#   'Percent of adults with a bachelors degree or higher  2013-17': 42,
#   'Civilian_labor_force_2017': 28581,
#   'Employed_2017': 27431,
#   'Unemployed_2017': 1150,
#   'Unemployment_rate_2017': 4,
#   'Civilian_labor_force_2018': 28832,
#   'Employed_2018': 27832,
#   'Unemployed_2018': 1000,
#   'Unemployment_rate_2018': 4,
#   'Median_Household_Income_2017.1': 48417},
#  {'id': 191,
#   'Overall Poverty 2017': 24577,
#   'Median_Household_Income_2017': 44592,
#   'POP_ESTIMATE_2017': 123257,
#   'POP_ESTIMATE_2018': 123248,
#   'N_POP_CHG_2017': -1191,
#   'N_POP_CHG_2018': -9,
#   'Births_2017': 1586,
#   'Births_2018': 1578,
#   'Deaths_2017': 1335,
#   'Deaths_2018': 1405,
#   'INTERNATIONAL_MIG_2017': 324,
#   'INTERNATIONAL_MIG_2018': 277,
#   'DOMESTIC_MIG_2017': -1773,
#   'DOMESTIC_MIG_2018': -455,
#   'NET_MIG_2017': -1449,
#   'NET_MIG_2018': -178,
#   'R_death_2017': 11,
#   'R_death_2018': 11,
#   'Less than a high school diploma  2013-17': 13597,
#   'High school diploma only  2013-17': 24638,
#   'Some college  associates degree  2013-17': 27817,
#   'Bachelors degree higher  2013-17': 16211,
#   'Percent of adults with less than a high school diploma  2013-17': 17,
#   'Percent of adults with a high school diploma only  2013-17': 30,
#   'Percent of adults completing some college or associates degree  2013-17': 34,
#   'Percent of adults with a bachelors degree or higher  2013-17': 20,
#   'Civilian_labor_force_2017': 53422,
#   'Employed_2017': 50758,
#   'Unemployed_2017': 2664,
#   'Unemployment_rate_2017': 5,
#   'Civilian_labor_force_2018': 52731,
#   'Employed_2018': 50460,
#   'Unemployed_2018': 2271,
#   'Unemployment_rate_2018': 4,
#   'Median_Household_Income_2017.1': 44592},
#  {'id': 193,
#   'Overall Poverty 2017': 12516,
#   'Median_Household_Income_2017': 42453,
#   'POP_ESTIMATE_2017': 68464,
#   'POP_ESTIMATE_2018': 68557,
#   'N_POP_CHG_2017': -90,
#   'N_POP_CHG_2018': 93,
#   'Births_2017': 682,
#   'Births_2018': 652,
#   'Deaths_2017': 813,
#   'Deaths_2018': 815,
#   'INTERNATIONAL_MIG_2017': 39,
#   'INTERNATIONAL_MIG_2018': 38,
#   'DOMESTIC_MIG_2017': 6,
#   'DOMESTIC_MIG_2018': 224,
#   'NET_MIG_2017': 45,
#   'NET_MIG_2018': 262,
#   'R_death_2017': 12,
#   'R_death_2018': 12,
#   'Less than a high school diploma  2013-17': 10590,
#   'High school diploma only  2013-17': 15602,
#   'Some college  associates degree  2013-17': 15131,
#   'Bachelors degree higher  2013-17': 7521,
#   'Percent of adults with less than a high school diploma  2013-17': 22,
#   'Percent of adults with a high school diploma only  2013-17': 32,
#   'Percent of adults completing some college or associates degree  2013-17': 31,
#   'Percent of adults with a bachelors degree or higher  2013-17': 15,
#   'Civilian_labor_force_2017': 30930,
#   'Employed_2017': 29625,
#   'Unemployed_2017': 1305,
#   'Unemployment_rate_2017': 4,
#   'Civilian_labor_force_2018': 30230,
#   'Employed_2018': 29102,
#   'Unemployed_2018': 1128,
#   'Unemployment_rate_2018': 4,
#   'Median_Household_Income_2017.1': 42453},
#  {'id': 195,
#   'Overall Poverty 2017': 14481,
#   'Median_Household_Income_2017': 44825,
#   'POP_ESTIMATE_2017': 81567,
#   'POP_ESTIMATE_2018': 81455,
#   'N_POP_CHG_2017': 197,
#   'N_POP_CHG_2018': -112,
#   'Births_2017': 945,
#   'Births_2018': 936,
#   'Deaths_2017': 849,
#   'Deaths_2018': 938,
#   'INTERNATIONAL_MIG_2017': 101,
#   'INTERNATIONAL_MIG_2018': 104,
#   'DOMESTIC_MIG_2017': 2,
#   'DOMESTIC_MIG_2018': -211,
#   'NET_MIG_2017': 103,
#   'NET_MIG_2018': -107,
#   'R_death_2017': 10,
#   'R_death_2018': 12,
#   'Less than a high school diploma  2013-17': 10631,
#   'High school diploma only  2013-17': 18128,
#   'Some college  associates degree  2013-17': 15918,
#   'Bachelors degree higher  2013-17': 10334,
#   'Percent of adults with less than a high school diploma  2013-17': 19,
#   'Percent of adults with a high school diploma only  2013-17': 33,
#   'Percent of adults completing some college or associates degree  2013-17': 29,
#   'Percent of adults with a bachelors degree or higher  2013-17': 19,
#   'Civilian_labor_force_2017': 35972,
#   'Employed_2017': 33397,
#   'Unemployed_2017': 2575,
#   'Unemployment_rate_2017': 7,
#   'Civilian_labor_force_2018': 35342,
#   'Employed_2018': 33175,
#   'Unemployed_2018': 2167,
#   'Unemployment_rate_2018': 6,
#   'Median_Household_Income_2017.1': 44825},
#  {'id': 197,
#   'Overall Poverty 2017': 5022,
#   'Median_Household_Income_2017': 46885,
#   'POP_ESTIMATE_2017': 37643,
#   'POP_ESTIMATE_2018': 37543,
#   'N_POP_CHG_2017': -20,
#   'N_POP_CHG_2018': -100,
#   'Births_2017': 374,
#   'Births_2018': 390,
#   'Deaths_2017': 419,
#   'Deaths_2018': 420,
#   'INTERNATIONAL_MIG_2017': -1,
#   'INTERNATIONAL_MIG_2018': -1,
#   'DOMESTIC_MIG_2017': 28,
#   'DOMESTIC_MIG_2018': -66,
#   'NET_MIG_2017': 27,
#   'NET_MIG_2018': -67,
#   'R_death_2017': 11,
#   'R_death_2018': 11,
#   'Less than a high school diploma  2013-17': 5488,
#   'High school diploma only  2013-17': 9193,
#   'Some college  associates degree  2013-17': 8679,
#   'Bachelors degree higher  2013-17': 3194,
#   'Percent of adults with less than a high school diploma  2013-17': 21,
#   'Percent of adults with a high school diploma only  2013-17': 35,
#   'Percent of adults completing some college or associates degree  2013-17': 33,
#   'Percent of adults with a bachelors degree or higher  2013-17': 12,
#   'Civilian_labor_force_2017': 17702,
#   'Employed_2017': 17011,
#   'Unemployed_2017': 691,
#   'Unemployment_rate_2017': 4,
#   'Civilian_labor_force_2018': 17791,
#   'Employed_2018': 17191,
#   'Unemployed_2018': 600,
#   'Unemployment_rate_2018': 3,
#   'Median_Household_Income_2017.1': 46885},
#  {'id': 199,
#   'Overall Poverty 2017': 2903,
#   'Median_Household_Income_2017': 41053,
#   'POP_ESTIMATE_2017': 17712,
#   'POP_ESTIMATE_2018': 17903,
#   'N_POP_CHG_2017': 94,
#   'N_POP_CHG_2018': 191,
#   'Births_2017': 153,
#   'Births_2018': 157,
#   'Deaths_2017': 212,
#   'Deaths_2018': 207,
#   'INTERNATIONAL_MIG_2017': 3,
#   'INTERNATIONAL_MIG_2018': 3,
#   'DOMESTIC_MIG_2017': 149,
#   'DOMESTIC_MIG_2018': 238,
#   'NET_MIG_2017': 152,
#   'NET_MIG_2018': 241,
#   'R_death_2017': 12,
#   'R_death_2018': 12,
#   'Less than a high school diploma  2013-17': 2188,
#   'High school diploma only  2013-17': 4366,
#   'Some college  associates degree  2013-17': 3910,
#   'Bachelors degree higher  2013-17': 2571,
#   'Percent of adults with less than a high school diploma  2013-17': 17,
#   'Percent of adults with a high school diploma only  2013-17': 34,
#   'Percent of adults completing some college or associates degree  2013-17': 30,
#   'Percent of adults with a bachelors degree or higher  2013-17': 20,
#   'Civilian_labor_force_2017': 7430,
#   'Employed_2017': 7094,
#   'Unemployed_2017': 336,
#   'Unemployment_rate_2017': 5,
#   'Civilian_labor_force_2018': 8245,
#   'Employed_2018': 7950,
#   'Unemployed_2018': 295,
#   'Unemployment_rate_2018': 4,
#   'Median_Household_Income_2017.1': 41053}]

# %%
# Dependencies
# ----------------------------------
# Imports the method used for connecting to DBs
from sqlalchemy import create_engine

# Imports the methods needed to abstract classes into tables
from sqlalchemy.ext.declarative import declarative_base

# Allow us to declare column types
from sqlalchemy import Column, Integer, String, Float, ARRAY

# %%
Base = declarative_base()

# Working with the SQLAlchemy ORM.
# Define a mapped class, which maps to rows of the NC Counties database table.

# Creates an NC CV Fatality class which will serve as the anchor points for our Tables.
    
class CensusData(Base):
    __tablename__ = 'NCCensusData'
    id = Column(Integer, primary_key=True)
    Overall_Poverty_2017 = Column(Integer)
    Median_Household_Income_2017 = Column(Integer)
    POP_ESTIMATE_2017 = Column(Integer)
    POP_ESTIMATE_2018 = Column(Integer)
    N_POP_CHG_2017 = Column(Integer)
    N_POP_CHG_2018 = Column(Integer) 
    Births_2017 = Column(Integer)
    Births_201 = Column(Integer)
    Deaths_2017 = Column(Integer)
    Deaths_2018 = Column(Integer)
    INTERNATIONAL_MIG_2017 = Column(Integer)
    INTERNATIONAL_MIG_2018 = Column(Integer)
    DOMESTIC_MIG_2017 = Column(Integer) 
    DOMESTIC_MIG_2018 = Column(Integer)
    NET_MIG_2017 = Column(Integer)
    NET_MIG_2018 = Column(Integer)
    R_death_2017 = Column(Integer)
    R_death_2018 = Column(Integer)
    Less_than_a_high_school_diploma_2013_17 = Column(Integer)
    High_school_diploma_only_2013_17 = Column(Integer)
    Some_college_or_associates_degree_2013_17 = Column(Integer)
    Bachelors_degree_higher_2013_17 = Column(Integer)
    Percent_of_adults_with_less_than_a_high_school_diploma_2013_17 = Column(Integer)
    Percent_of_adults_with_a_high_school_diploma_only_2013_17 = Column(Integer)
    Percent_of_adults_completing_some_college_or_associates_degree_2013_17 = Column(Integer)
    Percent_of_adults_with_a_bachelors_degree_or_higher_2013_17 = Column(Integer)
    Civilian_labor_force_2017 = Column(Integer)
    Employed_2017 = Column(Integer)
    Unemployed_2017 = Column(Integer)
    Unemployment_rate_2017 = Column(Integer)
    Civilian_labor_force_2018 = Column(Integer)
    Employed_2018 = Column(Integer)
    Unemployed_2018 = Column(Integer)
    Unemployment_rate_2018 = Column(Integer)

# %%
engine = create_engine("postgresql://postgres:postgres@localhost:5432/Project3")
conn = engine.connect()

# %%
Base.metadata.drop_all(engine)
Base.metadata.create_all(engine)

# %%
# Create a Session Object to Connect to DB
# ----------------------------------
from sqlalchemy.orm import Session
session = Session(bind=engine)

# %%
for xx in NCCVFatalityData:
    CData = CensusData(id=xx['id'],
    Overall_Poverty_2017=xx['Overall Poverty 2017'],
    Median_Household_Income_2017=int(xx['Median_Household_Income_2017']),
    POP_ESTIMATE_2017=int(xx['POP_ESTIMATE_2017']),
    POP_ESTIMATE_2018=int(xx['POP_ESTIMATE_2018']),
    N_POP_CHG_2017=int(xx['N_POP_CHG_2017']),
    N_POP_CHG_2018=int(xx['N_POP_CHG_2018']),
    Births_2017=int(xx['Births_2017']),
    Births_201=int(xx['Births_2018']),
    Deaths_2017=int(xx['Deaths_2017']),
    Deaths_2018=int(xx['Deaths_2018']),
    INTERNATIONAL_MIG_2017=int(xx['INTERNATIONAL_MIG_2017']),
    INTERNATIONAL_MIG_2018=int(xx['INTERNATIONAL_MIG_2018']),
    DOMESTIC_MIG_2017=int(xx['DOMESTIC_MIG_2017']),
    DOMESTIC_MIG_2018=int(xx['DOMESTIC_MIG_2018']),
    NET_MIG_2017=int(xx['NET_MIG_2017']),
    NET_MIG_2018=int(xx['NET_MIG_2018']),
    R_death_2017=int(xx['R_death_2017']),
    R_death_2018=int(xx['R_death_2018']),
    Less_than_a_high_school_diploma_2013_17=int(xx['Less than a high school diploma  2013-17']),
    High_school_diploma_only_2013_17=int(xx['High school diploma only  2013-17']),
    Some_college_or_associates_degree_2013_17=int(xx['Some college  associates degree  2013-17']),
    Bachelors_degree_higher_2013_17=int(xx['Bachelors degree higher  2013-17']),
    Percent_of_adults_with_less_than_a_high_school_diploma_2013_17=int(xx['Percent of adults with less than a high school diploma  2013-17']),
    Percent_of_adults_with_a_high_school_diploma_only_2013_17=int(xx['Percent of adults with a high school diploma only  2013-17']),
    Percent_of_adults_completing_some_college_or_associates_degree_2013_17=int(xx['Percent of adults completing some college or associates degree  2013-17']),
    Percent_of_adults_with_a_bachelors_degree_or_higher_2013_17=int(xx['Percent of adults with a bachelors degree or higher  2013-17']),
    Civilian_labor_force_2017=int(xx['Civilian_labor_force_2017']),
    Employed_2017=int(xx['Employed_2017']),
    Unemployed_2017=int(xx['Unemployed_2017']),
    Unemployment_rate_2017=int(xx['Unemployment_rate_2017']),
    Civilian_labor_force_2018=int(xx['Civilian_labor_force_2018']),
    Employed_2018=int(xx['Employed_2018']),
    Unemployed_2018=int(xx['Unemployed_2018']),
    Unemployment_rate_2018=int(xx['Unemployment_rate_2018']))
    session.add(CData) 
                  
session.commit()
